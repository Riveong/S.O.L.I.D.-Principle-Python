# %%
class Car:    
    def __init__(self, engine):
        self.engine = engine
 
    def start(self):
        self.engine.start()
 
class Engine:
    def start():
        print(",,,")


class DieselEngine:
    def start():
        print("haha diesel goes brrrr")

class PetrolEngine(EngineInterface):
    def start():
        pass
 
class HybridEngine(EngineInterface):
    def start():
        pass
 
class DieselEngine(EngineInterface):
    def start():
        pass



class Car:
    def __init__(self, engine):
        self.engine = engine
 
    def start(self):
        self.start()

class DieselEngine:
    def start():
        print("ok")



class Main:
    def __init__(self):
        fuelCar = Car(PetrolEngine())
        dieselCar = Car(DieselEngine())
        hybridCar = Car(HybridEngine())
 
        fuelCar.start()
        dieselCar.start()
        hybridCar.start()
